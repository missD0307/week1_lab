# %% [markdown]
# <a href="https://colab.research.google.com/github/missD0307/week1_lab/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Diyorabonu Aliyeva"

# %%
my_enrollment_number = "A85205225029"

# %%
my_hobby = "Swimming, Reading Books"

# %%
print("Hello, my name is {}, and my my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# Hello, my name is Diyorabonu Aliyeva, and my my enrollment number is A85205225029. I like Swimming, Reading Books.
